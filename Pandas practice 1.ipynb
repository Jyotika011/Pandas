# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv")
data
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %% [markdown]
# Problem 1:
# #Describe for cat and numerical column

# %%
data.dtypes
# Out:
# lat          float64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# dtype: object

# %%
data.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
data.dtypes=="object"
# Out:
# lat          False
# lng          False
# desc          True
# zip          False
# title         True
# timeStamp     True
# twp           True
# addr          True
# e            False
# dtype: bool

# %%
data.dtypes=="object"
a=data.dtypes[data.dtypes=="object"].index
a
data[a].describe()
# Out:
#                                                      desc  \
# count                                               99492
# unique                                              99455
# top     GREEN ST & E BASIN ST;  NORRISTOWN; Station 30...
# freq                                                    4
#
#                               title            timeStamp           twp  \
# count                         99492                99492         99449
# unique                          110                72577            68
# top     Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01  LOWER MERION
# freq                          23066                    8          8443
#
#                                      addr
# count                               98973
# unique                              21914
# top     SHANNONDELL DR & SHANNONDELL BLVD
# freq                                  938

# %% [markdown]
# Problem 2:
# #lat type cast it to int, perform group by and apply count on it

# %%
data["lat"]=data["lat"].apply(int)
data.head()
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4   40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %% [markdown]
# Problem 3
# #how many people are from same zip location

# %%
d2=data.groupby(["zip"]).size().reset_index(name="number of people")
d2.head()
# Out:
#        zip  number of people
# 0  17752.0                 1
# 1  18036.0                 2
# 2  18041.0               414
# 3  18054.0               326
# 4  18056.0                 6

# %% [markdown]
# Problem 4
# #check time stamp datatype and extract day in new col

# %%
data['day'] = pd.DatetimeIndex(data['timeStamp']).day
data.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e mon_sun  day
# ...

# %% [markdown]
# Problem 5
# #filter out all the zip codes which address starts with 'A'

# %%
import numpy as np
df=data[data['desc'].str.startswith('A')]  
df
df2=df[["desc","zip"]]
df2.head()
# Out:
#                                                   desc      zip
# 3    AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 43   ALLENDALE RD & WILLS BLVD; UPPER MERION; 2015-...  19406.0
# 48   AUTO PARK BLVD & LINFIELD TRAPPE RD; LIMERICK;...  19468.0
# 72   AVIGNON DR & DEAD END; LOWER MERION; 2015-12-1...      NaN
# 103  ADAMS ST & WALNUT ST; ROYERSFORD; 2015-12-10 @...  19468.0

# %% [markdown]
# problem 6
# 6) from title extract service detail

# %%
data.dtypes=="object"
a=data.dtypes[data.dtypes=="object"].index
a
data[a].describe()
# Out:
#                                                      desc  \
# count                                               99492
# unique                                              99455
# top     GREEN ST & E BASIN ST;  NORRISTOWN; Station 30...
# freq                                                    4
#
#                               title            timeStamp           twp  \
# count                         99492                99492         99449
# unique                          110                72577            68
# top     Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01  LOWER MERION
# freq                          23066                    8          8443
#
#                                      addr
# count                               98973
# unique                              21914
# top     SHANNONDELL DR & SHANNONDELL BLVD
# freq                                  938

# %%
data["title"].describe()
# Out:
# count                           99492
# unique                            110
# top       Traffic: VEHICLE ACCIDENT -
# freq                            23066
# Name: title, dtype: object
